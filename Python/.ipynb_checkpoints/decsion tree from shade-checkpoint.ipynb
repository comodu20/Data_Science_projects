# %%
#Question 2 (10 marks)

# We are aiming to fit a decision tree now to classify the binary response variable is_obese_only. Split your data to train and test, fit a decision tree to the training data, then apply the fitted decision tree to the test subset to calculate the F1-score using the predicted and true labels for the test data set. Consider the 70-30 rule for the train and test subset.

# Note that the binary response is is_obese_only and we are using all the other variables in the model directly as features. In your data splitting and model fitting process, please stick to the above mentioned random_state = random_state convention.

# Assign the value of F1 to answer_q2 with at least 4 decimal places.

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\omodu\anaconda3\My Work\Data repository\obesity.csv')

df.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1     0   2.0
# 1       0  21.0    1.52    56.0                               1     0   3.0
# 2       1  23.0    1.80    77.0                               1     0   2.0
# 3       1  27.0    1.80    87.0                               0     0   3.0
# 4       1  22.0    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  ...  TUE  CALC  MTRANS  Insufficient_Weight  \
# 0  3.0     2      0  ...  1.0     3       3                    0
# 1  3.0     2      1  ...  0.0     2       3                    0
# 2  3.0     2      0  ...  1.0     1       3                    0
# 3  3.0     2      0  ...  0.0     1       4                    0
# 4  1.0     2      0  ...  0.0     2       3                    0
#
#    Normal_Weight  Obesity_Type_I  Obesity_Type_II  Obesity_Type_III  \
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

df = pd.read_csv(r'C:\Users\omodu\anaconda3\My Work\Data repository\obesity.csv')
obesity_cleaned = df.drop(columns=['is_obese_only'])

X = obesity_cleaned.drop(columns=['is_obese_only'])
y = obesity_cleaned['is_obese_only']

 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

 

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

 

f1 = f1_score(y_test, y_pred)
print(f1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 8
#       5 from sklearn.metrics import f1_score
#       7 df = pd.read_csv(r'C:\Users\omodu\anaconda3\My Work\Data repository\obesity.csv')
# ----> 8 obesity_cleaned = df.drop(columns=['is_obese_only'])
#      10 X = obesity_cleaned.drop(columns=['is_obese_only'])
#      11 y = obesity_cleaned['is_obese_only']
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
